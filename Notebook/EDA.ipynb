# %%
import pandas as pd

# %%
pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in d:\new folder\mushroom classification\venv\lib\site-packages (6.23.2)
# Requirement already satisfied: psutil in d:\new folder\mushroom classification\venv\lib\site-packages (from ipykernel) (5.9.5)
# Requirement already satisfied: debugpy>=1.6.5 in d:\new folder\mushroom classification\venv\lib\site-packages (from ipykernel) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in d:\new folder\mushroom classification\venv\lib\site-packages (from ipykernel) (8.12.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\new folder\mushroom classification\venv\lib\site-packages (from ipykernel) (5.3.1)
# Requirement already satisfied: packaging in d:\new folder\mushroom classification\venv\lib\site-packages (from ipykernel) (23.1)
# Requirement already satisfied: tornado>=6.1 in d:\new folder\mushroom classification\venv\lib\site-packages (from ipykernel) (6.3.2)
# Requirement already satisfied: traitlets>=5.4.0 in d:\new folder\mushroom classification\venv\lib\site-packages (from ipykernel) (5.9.0)
# Requirement already satisfied: comm>=0.1.1 in d:\new folder\mushroom classification\venv\lib\site-packages (from ipykernel) (0.1.3)
# Requirement already satisfied: pyzmq>=20 in d:\new folder\mushroom classification\venv\lib\site-packages (from ipykernel) (25.1.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\new folder\mushroom classification\venv\lib\site-packages (from ipykernel) (8.2.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\new folder\mushroom classification\venv\lib\site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: nest-asyncio in d:\new folder\mushroom classification\venv\lib\site-packages (from ipykernel) (1.5.6)
# Requirement already satisfied: typing-extensions in d:\new folder\mushroom classification\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (4.6.3)
# Requirement already satisfied: decorator in d:\new folder\mushroom classification\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in d:\new folder\mushroom classification\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.15.1)
# Requirement already satisfied: stack-data in d:\new folder\mushroom classification\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.2)
# Requirement already satisfied: jedi>=0.16 in d:\new folder\mushroom classification\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.18.2)
# Requirement already satisfied: pickleshare in d:\new folder\mushroom classification\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: backcall in d:\new folder\mushroom classification\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in d:\new folder\mushroom classification\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.38)
# Requirement already satisfied: colorama in d:\new folder\mushroom classification\venv\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: importlib-metadata>=4.8.3 in d:\new folder\mushroom classification\venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel) (6.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\new folder\mushroom classification\venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in d:\new folder\mushroom classification\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (3.5.3)
# Requirement already satisfied: pywin32>=300 in d:\new folder\mushroom classification\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (306)
# Requirement already satisfied: zipp>=0.5 in d:\new folder\mushroom classification\venv\lib\site-packages (from importlib-metadata>=4.8.3->jupyter-client>=6.1.12->ipykernel) (3.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\new folder\mushroom classification\venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: wcwidth in d:\new folder\mushroom classification\venv\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel) (0.2.6)
# Requirement already satisfied: six>=1.5 in d:\new folder\mushroom classification\venv\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in d:\new folder\mushroom classification\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in d:\new folder\mushroom classification\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: pure-eval in d:\new folder\mushroom classification\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_csv("data/mushrooms.csv")

# %%
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0               c         n          k  ...                        s
# 1               c         b          k  ...                        s
# 2               c         b          n  ...                        s
# 3               c         n          n  ...                        s
# 4               w         b          k  ...                        s
# ...           ...       ...        ...  ...                      ...
# 8119            c         b          y  ...                        s
# 8120            c         b          y  ...                        s
# 8121            c         b          n  ...                        s
# 8122            c         n          b  ...                        k
# 8123            c         b          y  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         w                      w         p          w
# 1                         w                      w         p          w
# 2                         w                      w         p          w
# 3                         w                      w         p          w
# 4                         w                      w         p          w
# ...                     ...                    ...       ...        ...
# 8119                      o                      o         p          o
# 8120                      o                      o         p          n
# 8121                      o                      o         p          o
# 8122                      w                      w         p          w
# 8123                      o                      o         p          o
#
#      ring-number ring-type spore-print-color population habitat
# 0              o         p                 k          s       u
# 1              o         p                 n          n       g
# 2              o         p                 n          n       m
# 3              o         p                 k          s       u
# 4              o         e                 n          a       g
# ...          ...       ...               ...        ...     ...
# 8119           o         p                 b          c       l
# 8120           o         p                 b          v       l
# 8121           o         p                 b          c       l
# 8122           o         e                 w          v       l
# 8123           o         p                 o          c       l
#
# [8124 rows x 23 columns]

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
df.tail()
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 8119            c         b          y  ...                        s
# 8120            c         b          y  ...                        s
# 8121            c         b          n  ...                        s
# 8122            c         n          b  ...                        k
# 8123            c         b          y  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 8119                      o                      o         p          o
# 8120                      o                      o         p          n
# 8121                      o                      o         p          o
# 8122                      w                      w         p          w
# 8123                      o                      o         p          o
#
#      ring-number ring-type spore-print-color population habitat
# 8119           o         p                 b          c       l
# 8120           o         p                 b          v       l
# 8121           o         p                 b          c       l
# 8122           o         e                 w          v       l
# 8123           o         p                 o          c       l
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
#  13  stalk-surface-below-ring  8124 non-null   object
#  14  stalk-color-above-ring    8124 non-null   object
#  15  stalk-color-below-ring    8124 non-null   object
#  16  veil-type                 8124 non-null   object
#  17  veil-color                8124 non-null   object
#  18  ring-number               8124 non-null   object
#  19  ring-type                 8124 non-null   object
#  20  spore-print-color         8124 non-null   object
#  21  population                8124 non-null   object
#  22  habitat                   8124 non-null   object
# dtypes: object(23)
# memory usage: 1.4+ MB

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
df.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# top                         w                      w         p          w
# freq                     4464                   4384      8124       7924
#
#        ring-number ring-type spore-print-color population habitat
# count         8124      8124              8124       8124    8124
# unique           3         5                 9          6       7
# top              o         p                 w          v       d
# freq          7488      3968              2388       4040    3148
#
# [4 rows x 23 columns]

# %%
df.describe(include="all").T
# Out:
#                          count unique top  freq
# class                     8124      2   e  4208
# cap-shape                 8124      6   x  3656
# cap-surface               8124      4   y  3244
# cap-color                 8124     10   n  2284
# bruises                   8124      2   f  4748
# odor                      8124      9   n  3528
# gill-attachment           8124      2   f  7914
# gill-spacing              8124      2   c  6812
# gill-size                 8124      2   b  5612
# gill-color                8124     12   b  1728
# stalk-shape               8124      2   t  4608
# stalk-root                8124      5   b  3776
# stalk-surface-above-ring  8124      4   s  5176
# stalk-surface-below-ring  8124      4   s  4936
# stalk-color-above-ring    8124      9   w  4464
# stalk-color-below-ring    8124      9   w  4384
# veil-type                 8124      1   p  8124
# veil-color                8124      4   w  7924
# ring-number               8124      3   o  7488
# ring-type                 8124      5   p  3968
# spore-print-color         8124      9   w  2388
# population                8124      6   v  4040
# habitat                   8124      7   d  3148

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8119    False
# 8120    False
# 8121    False
# 8122    False
# 8123    False
# Length: 8124, dtype: bool

# %%
df.drop_duplicates()
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         2          6            3          5        2     7
# 1         1          6            3         10        2     1
# 2         1          1            3          9        2     4
# 3         2          6            4          9        2     7
# 4         1          6            3          4        1     6
# ...     ...        ...          ...        ...      ...   ...
# 8119      1          4            3          5        1     6
# 8120      1          6            3          5        1     6
# 8121      1          3            3          5        1     6
# 8122      2          4            4          5        1     9
# 8123      1          6            3          5        1     6
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   2             1          2           5  ...
# 1                   2             1          1           5  ...
# 2                   2             1          1           6  ...
# 3                   2             1          2           6  ...
# 4                   2             2          1           5  ...
# ...               ...           ...        ...         ...  ...
# 8119                1             1          1          12  ...
# 8120                1             1          1          12  ...
# 8121                1             1          1           6  ...
# 8122                2             1          2           1  ...
# 8123                1             1          1          12  ...
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 0                            3                       8
# 1                            3                       8
# 2                            3                       8
# 3                            3                       8
# 4                            3                       8
# ...                        ...                     ...
# 8119                         3                       6
# 8120                         3                       6
# 8121                         3                       6
# 8122                         2                       8
# 8123                         3                       6
#
#       stalk-color-below-ring  veil-type  veil-color  ring-number  ring-type  \
# 0                          8          1           3            2          5
# 1                          8          1           3            2          5
# 2                          8          1           3            2          5
# 3                          8          1           3            2          5
# 4                          8          1           3            2          1
# ...                      ...        ...         ...          ...        ...
# 8119                       6          1           2            2          5
# 8120                       6          1           1            2          5
# 8121                       6          1           2            2          5
# 8122                       8          1           3            2          1
# 8123                       6          1           2            2          5
#
#       spore-print-color  population  habitat
# 0                     3           4        6
# 1                     4           3        2
# 2                     4           3        4
# 3                     3           4        6
# 4                     4           1        2
# ...                 ...         ...      ...
# 8119                  1           2        3
# 8120                  1           5        3
# 8121                  1           2        3
# 8122                  8           5        3
# 8123                  5           2        3
#
# [8124 rows x 23 columns]

# %%
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      2          6            3          5        2     7                2
# 1      1          6            3         10        2     1                2
# 2      1          1            3          9        2     4                2
# 3      2          6            4          9        2     7                2
# 4      1          6            3          4        1     6                2
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             1          2           5  ...                         3
# 1             1          1           5  ...                         3
# 2             1          1           6  ...                         3
# 3             1          2           6  ...                         3
# 4             2          1           5  ...                         3
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                       8                       8          1           3
# 1                       8                       8          1           3
# 2                       8                       8          1           3
# 3                       8                       8          1           3
# 4                       8                       8          1           3
#
#    ring-number  ring-type  spore-print-color  population  habitat
# 0            2          5                  3           4        6
# 1            2          5                  4           3        2
# 2            2          5                  4           3        4
# 3            2          5                  3           4        6
# 4            2          1                  4           1        2
#
# [5 rows x 23 columns]

# %%
numeric_columns=df.columns[df.dtypes!="object"]
categorical_columns=df.columns[df.dtypes=="object"]

# %%
numeric_columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
categorical_columns
# Out:
# Index([], dtype='object')

# %%
df[numeric_columns].describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      1.482029     4.348104     2.827671     5.504677     1.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%       1.000000     3.000000     1.000000     4.000000     1.000000
# 50%       1.000000     4.000000     3.000000     5.000000     1.000000
# 75%       2.000000     6.000000     4.000000     9.000000     2.000000
# max       2.000000     6.000000     4.000000    10.000000     2.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      5.144756         1.974151      1.161497     1.309207     5.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# min       1.000000         1.000000      1.000000     1.000000     1.000000
# 25%       3.000000         2.000000      1.000000     1.000000     3.000000
# 50%       6.000000         2.000000      1.000000     1.000000     6.000000
# 75%       6.000000         2.000000      1.000000     2.000000     8.000000
# max       9.000000         2.000000      2.000000     2.000000    12.000000
#
#        ...  stalk-surface-below-ring  stalk-color-above-ring  \
# count  ...               8124.000000             8124.000000
# mean   ...                  2.603644                6.816347
# std    ...                  0.675974                1.901747
# min    ...                  1.000000                1.000000
# 25%    ...                  2.000000                7.000000
# 50%    ...                  3.000000                8.000000
# 75%    ...                  3.000000                8.000000
# max    ...                  4.000000                9.000000
#
#        stalk-color-below-ring  veil-type   veil-color  ring-number  \
# count             8124.000000     8124.0  8124.000000  8124.000000
# mean                 6.794682        1.0     2.965534     2.069424
# std                  1.907291        0.0     0.242669     0.271064
# min                  1.000000        1.0     1.000000     1.000000
# 25%                  7.000000        1.0     3.000000     2.000000
# 50%                  8.000000        1.0     3.000000     2.000000
# 75%                  8.000000        1.0     3.000000     2.000000
# max                  9.000000        1.0     4.000000     3.000000
#
#          ring-type  spore-print-color   population      habitat
# count  8124.000000        8124.000000  8124.000000  8124.000000
# mean      3.291974           4.596750     4.644018     2.508616
# std       1.801672           2.382663     1.252082     1.719975
# min       1.000000           1.000000     1.000000     1.000000
# 25%       1.000000           3.000000     4.000000     1.000000
# 50%       3.000000           4.000000     5.000000     2.000000
# 75%       5.000000           8.000000     5.000000     3.000000
# max       5.000000           9.000000     6.000000     7.000000
#
# [8 rows x 23 columns]

# %%
import statistics as stats
import numpy as np

# %%
np.mean(df)
# Out:
# 3.2400616530730204

# %%
np.median(df)
# Out:
# 2.0

# %%
stats.mode(df)
# Out:
# 'class'

# %% [markdown]
# ### correlation and covariance

# %%
df.corr()
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# stalk-surface-above-ring -0.334593  -0.030417     0.089090  -0.060837
# stalk-surface-below-ring -0.298801  -0.032591     0.107965  -0.047710
# stalk-color-above-ring   -0.154003  -0.031659     0.066050   0.002364
# stalk-color-below-ring   -0.146730  -0.030390     0.068885   0.008057
# veil-type                      NaN        NaN          NaN        NaN
# veil-color                0.145142   0.072560    -0.016603   0.036130
# ring-number              -0.214366  -0.106534    -0.026147  -0.005822
# ring-type                -0.411771  -0.025457    -0.106407   0.162513
# spore-print-color         0.171961  -0.073416     0.230364  -0.293523
# population                0.298686   0.063413     0.021555  -0.144770
# habitat                   0.217179  -0.042221     0.163887   0.033925
#
#                            bruises      odor  gill-attachment  gill-spacing  \
# class                    -0.501530 -0.093552         0.129200     -0.348387
# cap-shape                -0.035374 -0.021935         0.078865      0.013196
# cap-surface               0.070228  0.045233        -0.034180     -0.282306
# cap-color                -0.000764 -0.387121         0.041436      0.144259
# bruises                   1.000000 -0.061825         0.137359     -0.299473
# odor                     -0.061825  1.000000        -0.059590      0.063936
# gill-attachment           0.137359 -0.059590         1.000000      0.071489
# gill-spacing             -0.299473  0.063936         0.071489      1.000000
# gill-size                -0.369596  0.310495         0.108984     -0.108333
# gill-color                0.527120 -0.129213        -0.128567      0.100193
# stalk-shape               0.099364  0.459766         0.186485      0.080895
# stalk-root                0.244188 -0.205215         0.144063      0.350548
# stalk-surface-above-ring  0.460824  0.118617        -0.088916     -0.212359
# stalk-surface-below-ring  0.458983  0.061820        -0.116177     -0.213775
# stalk-color-above-ring    0.083538  0.174532         0.099299      0.274574
# stalk-color-below-ring    0.092874  0.169407         0.097160      0.253505
# veil-type                      NaN       NaN              NaN           NaN
# veil-color                0.119770 -0.057747         0.897518      0.073363
# ring-number               0.056788  0.111905         0.093236      0.243014
# ring-type                 0.692973 -0.281387        -0.146689     -0.195897
# spore-print-color        -0.285008  0.469055        -0.029524      0.047323
# population                0.088137 -0.043623         0.165575     -0.529253
# habitat                  -0.075095 -0.026610        -0.030304     -0.154680
#
#                           gill-size  gill-color  ...  \
# class                      0.540024   -0.530566  ...
# cap-shape                  0.054050   -0.006039  ...
# cap-surface                0.208100   -0.161017  ...
# cap-color                 -0.169464    0.084659  ...
# bruises                   -0.369596    0.527120  ...
# odor                       0.310495   -0.129213  ...
# gill-attachment            0.108984   -0.128567  ...
# gill-spacing              -0.108333    0.100193  ...
# gill-size                  1.000000   -0.516736  ...
# gill-color                -0.516736    1.000000  ...
# stalk-shape                0.214576   -0.175699  ...
# stalk-root                -0.344345    0.315080  ...
# stalk-surface-above-ring   0.056310    0.224287  ...
# stalk-surface-below-ring   0.010894    0.257224  ...
# stalk-color-above-ring     0.296548   -0.058299  ...
# stalk-color-below-ring     0.278708   -0.074781  ...
# veil-type                       NaN         NaN  ...
# veil-color                 0.103809   -0.097583  ...
# ring-number               -0.171362    0.096054  ...
# ring-type                 -0.460872    0.629398  ...
# spore-print-color          0.622991   -0.416135  ...
# population                 0.147682   -0.034090  ...
# habitat                    0.161418   -0.202972  ...
#
#                           stalk-surface-below-ring  stalk-color-above-ring  \
# class                                    -0.298801               -0.154003
# cap-shape                                -0.032591               -0.031659
# cap-surface                               0.107965                0.066050
# cap-color                                -0.047710                0.002364
# bruises                                   0.458983                0.083538
# odor                                      0.061820                0.174532
# gill-attachment                          -0.116177                0.099299
# gill-spacing                             -0.213775                0.274574
# gill-size                                 0.010894                0.296548
# gill-color                                0.257224               -0.058299
# stalk-shape                              -0.034399                0.223439
# stalk-root                                0.087454                0.157140
# stalk-surface-above-ring                  0.437164                0.132708
# stalk-surface-below-ring                  1.000000                0.106933
# stalk-color-above-ring                    0.106933                1.000000
# stalk-color-below-ring                    0.110656                0.491510
# veil-type                                      NaN                     NaN
# veil-color                               -0.077284                0.067377
# ring-number                               0.040006                0.084917
# ring-type                                 0.394644               -0.048878
# spore-print-color                         0.130974                0.271533
# population                                0.046797               -0.240261
# habitat                                  -0.039628                0.042561
#
#                           stalk-color-below-ring  veil-type  veil-color  \
# class                                  -0.146730        NaN    0.145142
# cap-shape                              -0.030390        NaN    0.072560
# cap-surface                             0.068885        NaN   -0.016603
# cap-color                               0.008057        NaN    0.036130
# bruises                                 0.092874        NaN    0.119770
# odor                                    0.169407        NaN   -0.057747
# gill-attachment                         0.097160        NaN    0.897518
# gill-spacing                            0.253505        NaN    0.073363
# gill-size                               0.278708        NaN    0.103809
# gill-color                             -0.074781        NaN   -0.097583
# stalk-shape                             0.235794        NaN    0.162604
# stalk-root                              0.159805        NaN    0.156213
# stalk-surface-above-ring                0.142835        NaN   -0.090591
# stalk-surface-below-ring                0.110656        NaN   -0.077284
# stalk-color-above-ring                  0.491510        NaN    0.067377
# stalk-color-below-ring                  1.000000        NaN    0.065567
# veil-type                                    NaN        NaN         NaN
# veil-color                              0.065567        NaN    1.000000
# ring-number                             0.087580        NaN    0.036380
# ring-type                              -0.034284        NaN   -0.143673
# spore-print-color                       0.254518        NaN   -0.003600
# population                             -0.242792        NaN    0.124924
# habitat                                 0.041594        NaN   -0.040581
#
#                           ring-number  ring-type  spore-print-color  \
# class                       -0.214366  -0.411771           0.171961
# cap-shape                   -0.106534  -0.025457          -0.073416
# cap-surface                 -0.026147  -0.106407           0.230364
# cap-color                   -0.005822   0.162513          -0.293523
# bruises                      0.056788   0.692973          -0.285008
# odor                         0.111905  -0.281387           0.469055
# gill-attachment              0.093236  -0.146689          -0.029524
# gill-spacing                 0.243014  -0.195897           0.047323
# gill-size                   -0.171362  -0.460872           0.622991
# gill-color                   0.096054   0.629398          -0.416135
# stalk-shape                 -0.293221  -0.291444           0.258831
# stalk-root                  -0.247357   0.210155          -0.536996
# stalk-surface-above-ring     0.107904   0.390091           0.100764
# stalk-surface-below-ring     0.040006   0.394644           0.130974
# stalk-color-above-ring       0.084917  -0.048878           0.271533
# stalk-color-below-ring       0.087580  -0.034284           0.254518
# veil-type                         NaN        NaN                NaN
# veil-color                   0.036380  -0.143673          -0.003600
# ring-number                  1.000000   0.058312           0.338417
# ring-type                    0.058312   1.000000          -0.487048
# spore-print-color            0.338417  -0.487048           1.000000
# population                  -0.242020   0.211763          -0.126859
# habitat                      0.235835  -0.212080           0.185954
#
#                           population   habitat
# class                       0.298686  0.217179
# cap-shape                   0.063413 -0.042221
# cap-surface                 0.021555  0.163887
# cap-color                  -0.144770  0.033925
# bruises                     0.088137 -0.075095
# odor                       -0.043623 -0.026610
# gill-attachment             0.165575 -0.030304
# gill-spacing               -0.529253 -0.154680
# gill-size                   0.147682  0.161418
# gill-color                 -0.034090 -0.202972
# stalk-shape                 0.087383 -0.269216
# stalk-root                 -0.306747 -0.007668
# stalk-surface-above-ring    0.079604 -0.058076
# stalk-surface-below-ring    0.046797 -0.039628
# stalk-color-above-ring     -0.240261  0.042561
# stalk-color-below-ring     -0.242792  0.041594
# veil-type                        NaN       NaN
# veil-color                  0.124924 -0.040581
# ring-number                -0.242020  0.235835
# ring-type                   0.211763 -0.212080
# spore-print-color          -0.126859  0.185954
# population                  1.000000 -0.174529
# habitat                    -0.174529  1.000000
#
# [23 rows x 23 columns]

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.cov()
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     0.249708   0.042450     0.109669  -0.039926
# cap-shape                 0.042450   2.573872    -0.099551  -0.196877
# cap-surface               0.109669  -0.099551     1.512586  -0.060747
# cap-color                -0.039926  -0.196877    -0.060747   6.481204
# bruises                  -0.123517  -0.027970     0.042568  -0.000959
# odor                     -0.098346  -0.074033     0.117033  -2.073310
# gill-attachment           0.010246   0.020079    -0.006671   0.016740
# gill-spacing             -0.064068   0.007791    -0.127774   0.135155
# gill-size                 0.124725   0.040079     0.118293  -0.199403
# gill-color               -0.938648  -0.034300    -0.701101   0.763042
# stalk-shape              -0.025260   0.050712    -0.008606  -0.575841
# stalk-root               -0.201153   0.051396    -0.164752   0.867885
# stalk-surface-above-ring -0.103907  -0.030327     0.068093  -0.096252
# stalk-surface-below-ring -0.100932  -0.035345     0.089758  -0.082105
# stalk-color-above-ring   -0.146352  -0.096593     0.154485   0.011446
# stalk-color-below-ring   -0.139847  -0.092991     0.161585   0.039124
# veil-type                 0.000000   0.000000     0.000000   0.000000
# veil-color                0.017600   0.028249    -0.004955   0.022321
# ring-number              -0.029037  -0.046329    -0.008717  -0.004018
# ring-type                -0.370722  -0.073582    -0.235779   0.745403
# spore-print-color         0.204743  -0.280636     0.675052  -1.780460
# population                0.186880   0.127381     0.033193  -0.461464
# habitat                   0.186662  -0.116505     0.346678   0.148550
#
#                            bruises      odor  gill-attachment  gill-spacing  \
# class                    -0.123517 -0.098346         0.010246     -0.064068
# cap-shape                -0.027970 -0.074033         0.020079      0.007791
# cap-surface               0.042568  0.117033        -0.006671     -0.127774
# cap-color                -0.000959 -2.073310         0.016740      0.135155
# bruises                   0.242900 -0.064102         0.010743     -0.054317
# odor                     -0.064102  4.425676        -0.019894      0.049499
# gill-attachment           0.010743 -0.019894         0.025184      0.004175
# gill-spacing             -0.054317  0.049499         0.004175      0.135432
# gill-size                -0.084191  0.301905         0.007994     -0.018427
# gill-color                0.919750 -0.962374        -0.072234      0.130541
# stalk-shape               0.024265  0.479252         0.014664      0.014751
# stalk-root                0.127702 -0.458097         0.024259      0.136888
# stalk-surface-above-ring  0.141144  0.155078        -0.008769     -0.048567
# stalk-surface-below-ring  0.152911  0.087913        -0.012463     -0.053180
# stalk-color-above-ring    0.078298  0.698261         0.029968      0.192165
# stalk-color-below-ring    0.087302  0.679731         0.029408      0.177936
# veil-type                 0.000000  0.000000         0.000000      0.000000
# veil-color                0.014324 -0.029480         0.034564      0.006552
# ring-number               0.007586  0.063814         0.004011      0.024242
# ring-type                 0.615326 -1.066522        -0.041941     -0.129887
# spore-print-color        -0.334683  2.351129        -0.011164      0.041495
# population                0.054388 -0.114904         0.032900     -0.243869
# habitat                  -0.063657 -0.096286        -0.008272     -0.097908
#
#                           gill-size  gill-color  ...  \
# class                      0.124725   -0.938648  ...
# cap-shape                  0.040079   -0.034300  ...
# cap-surface                0.118293   -0.701101  ...
# cap-color                 -0.199403    0.763042  ...
# bruises                   -0.084191    0.919750  ...
# odor                       0.301905   -0.962374  ...
# gill-attachment            0.007994   -0.072234  ...
# gill-spacing              -0.018427    0.130541  ...
# gill-size                  0.213624   -0.845554  ...
# gill-color                -0.845554   12.534142  ...
# stalk-shape                0.049141   -0.308215  ...
# stalk-root                -0.168880    1.183660  ...
# stalk-surface-above-ring   0.016174    0.493473  ...
# stalk-surface-below-ring   0.003404    0.615586  ...
# stalk-color-above-ring     0.260660   -0.392522  ...
# stalk-color-below-ring     0.245692   -0.504959  ...
# veil-type                  0.000000    0.000000  ...
# veil-color                 0.011643   -0.083837  ...
# ring-number               -0.021469    0.092179  ...
# ring-type                 -0.383779    4.014657  ...
# spore-print-color          0.686072   -3.510304  ...
# population                 0.085464   -0.151114  ...
# habitat                    0.128321   -1.235966  ...
#
#                           stalk-surface-below-ring  stalk-color-above-ring  \
# class                                    -0.100932               -0.146352
# cap-shape                                -0.035345               -0.096593
# cap-surface                               0.089758                0.154485
# cap-color                                -0.082105                0.011446
# bruises                                   0.152911                0.078298
# odor                                      0.087913                0.698261
# gill-attachment                          -0.012463                0.029968
# gill-spacing                             -0.053180                0.192165
# gill-size                                 0.003404                0.260660
# gill-color                                0.615586               -0.392522
# stalk-shape                              -0.011522                0.210547
# stalk-root                                0.062729                0.317102
# stalk-surface-above-ring                  0.183649                0.156842
# stalk-surface-below-ring                  0.456941                0.137466
# stalk-color-above-ring                    0.137466                3.616643
# stalk-color-below-ring                    0.142666                1.782798
# veil-type                                 0.000000                0.000000
# veil-color                               -0.012678                0.031094
# ring-number                               0.007330                0.043775
# ring-type                                 0.480630               -0.167472
# spore-print-color                         0.210949                1.230377
# population                                0.039608               -0.572095
# habitat                                  -0.046074                0.139217
#
#                           stalk-color-below-ring  veil-type  veil-color  \
# class                                  -0.139847        0.0    0.017600
# cap-shape                              -0.092991        0.0    0.028249
# cap-surface                             0.161585        0.0   -0.004955
# cap-color                               0.039124        0.0    0.022321
# bruises                                 0.087302        0.0    0.014324
# odor                                    0.679731        0.0   -0.029480
# gill-attachment                         0.029408        0.0    0.034564
# gill-spacing                            0.177936        0.0    0.006552
# gill-size                               0.245692        0.0    0.011643
# gill-color                             -0.504959        0.0   -0.083837
# stalk-shape                             0.222837        0.0    0.019552
# stalk-root                              0.323420        0.0    0.040224
# stalk-surface-above-ring                0.169302        0.0   -0.013662
# stalk-surface-below-ring                0.142666        0.0   -0.012678
# stalk-color-above-ring                  1.782798        0.0    0.031094
# stalk-color-below-ring                  3.637761        0.0    0.030347
# veil-type                               0.000000        0.0    0.000000
# veil-color                              0.030347        0.0    0.058888
# ring-number                             0.045279        0.0    0.002393
# ring-type                              -0.117812        0.0   -0.062815
# spore-print-color                       1.156639        0.0   -0.002082
# population                             -0.579808        0.0    0.037957
# habitat                                 0.136449        0.0   -0.016938
#
#                           ring-number  ring-type  spore-print-color  \
# class                       -0.029037  -0.370722           0.204743
# cap-shape                   -0.046329  -0.073582          -0.280636
# cap-surface                 -0.008717  -0.235779           0.675052
# cap-color                   -0.004018   0.745403          -1.780460
# bruises                      0.007586   0.615326          -0.334683
# odor                         0.063814  -1.066522           2.351129
# gill-attachment              0.004011  -0.041941          -0.011164
# gill-spacing                 0.024242  -0.129887           0.041495
# gill-size                   -0.021469  -0.383779           0.686072
# gill-color                   0.092179   4.014657          -3.510304
# stalk-shape                 -0.039383  -0.260177           0.305574
# stalk-root                  -0.071147   0.401768          -1.357664
# stalk-surface-above-ring     0.018177   0.436772           0.149204
# stalk-surface-below-ring     0.007330   0.480630           0.210949
# stalk-color-above-ring       0.043775  -0.167472           1.230377
# stalk-color-below-ring       0.045279  -0.117812           1.156639
# veil-type                    0.000000   0.000000           0.000000
# veil-color                   0.002393  -0.062815          -0.002082
# ring-number                  0.073476   0.028478           0.218569
# ring-type                    0.028478   3.246022          -2.090791
# spore-print-color            0.218569  -2.090791           5.677084
# population                  -0.082140   0.477704          -0.378456
# habitat                      0.109952  -0.657200           0.762062
#
#                           population   habitat
# class                       0.186880  0.186662
# cap-shape                   0.127381 -0.116505
# cap-surface                 0.033193  0.346678
# cap-color                  -0.461464  0.148550
# bruises                     0.054388 -0.063657
# odor                       -0.114904 -0.096286
# gill-attachment             0.032900 -0.008272
# gill-spacing               -0.243869 -0.097908
# gill-size                   0.085464  0.128321
# gill-color                 -0.151114 -1.235966
# stalk-shape                 0.054212 -0.229436
# stalk-root                 -0.407542 -0.013996
# stalk-surface-above-ring    0.061941 -0.062078
# stalk-surface-below-ring    0.039608 -0.046074
# stalk-color-above-ring     -0.572095  0.139217
# stalk-color-below-ring     -0.579808  0.136449
# veil-type                   0.000000  0.000000
# veil-color                  0.037957 -0.016938
# ring-number                -0.082140  0.109952
# ring-type                   0.477704 -0.657200
# spore-print-color          -0.378456  0.762062
# population                  1.567709 -0.375856
# habitat                    -0.375856  2.958316
#
# [23 rows x 23 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
plt.figure(figsize=(10,10))
x=1
for i in numeric_columns:
    sns.histplot(data=df,x=i,kde=True)
    print("\n")
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
plt.figure(figsize=(10,10))
x=1
for i in categorical_columns:
    sns.histplot(data=df,x=i,kde=True)
    print("\n")
    plt.show()

# %%
categorical_columns=[]
def feature_encode(categorical_columns):
    for label,content in df.items():
        if label not in categorical_columns:
            df[label]=pd.Categorical(content).codes+1

feature_encode(categorical_columns)

# %%
df.tail()
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 8119      1          4            3          5        1     6
# 8120      1          6            3          5        1     6
# 8121      1          3            3          5        1     6
# 8122      2          4            4          5        1     9
# 8123      1          6            3          5        1     6
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 8119                1             1          1          12  ...
# 8120                1             1          1          12  ...
# 8121                1             1          1           6  ...
# 8122                2             1          2           1  ...
# 8123                1             1          1          12  ...
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 8119                         3                       6
# 8120                         3                       6
# 8121                         3                       6
# 8122                         2                       8
# 8123                         3                       6
#
#       stalk-color-below-ring  veil-type  veil-color  ring-number  ring-type  \
# 8119                       6          1           2            2          5
# 8120                       6          1           1            2          5
# 8121                       6          1           2            2          5
# 8122                       8          1           3            2          1
# 8123                       6          1           2            2          5
#
#       spore-print-color  population  habitat
# 8119                  1           2        3
# 8120                  1           5        3
# 8121                  1           2        3
# 8122                  8           5        3
# 8123                  5           2        3
#
# [5 rows x 23 columns]

# %%
clean_data=df

# %%
clean_data
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         2          6            3          5        2     7
# 1         1          6            3         10        2     1
# 2         1          1            3          9        2     4
# 3         2          6            4          9        2     7
# 4         1          6            3          4        1     6
# ...     ...        ...          ...        ...      ...   ...
# 8119      1          4            3          5        1     6
# 8120      1          6            3          5        1     6
# 8121      1          3            3          5        1     6
# 8122      2          4            4          5        1     9
# 8123      1          6            3          5        1     6
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   2             1          2           5  ...
# 1                   2             1          1           5  ...
# 2                   2             1          1           6  ...
# 3                   2             1          2           6  ...
# 4                   2             2          1           5  ...
# ...               ...           ...        ...         ...  ...
# 8119                1             1          1          12  ...
# 8120                1             1          1          12  ...
# 8121                1             1          1           6  ...
# 8122                2             1          2           1  ...
# 8123                1             1          1          12  ...
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 0                            3                       8
# 1                            3                       8
# 2                            3                       8
# 3                            3                       8
# 4                            3                       8
# ...                        ...                     ...
# 8119                         3                       6
# 8120                         3                       6
# 8121                         3                       6
# 8122                         2                       8
# 8123                         3                       6
#
#       stalk-color-below-ring  veil-type  veil-color  ring-number  ring-type  \
# 0                          8          1           3            2          5
# 1                          8          1           3            2          5
# 2                          8          1           3            2          5
# 3                          8          1           3            2          5
# 4                          8          1           3            2          1
# ...                      ...        ...         ...          ...        ...
# 8119                       6          1           2            2          5
# 8120                       6          1           1            2          5
# 8121                       6          1           2            2          5
# 8122                       8          1           3            2          1
# 8123                       6          1           2            2          5
#
#       spore-print-color  population  habitat
# 0                     3           4        6
# 1                     4           3        2
# 2                     4           3        4
# 3                     3           4        6
# 4                     4           1        2
# ...                 ...         ...      ...
# 8119                  1           2        3
# 8120                  1           5        3
# 8121                  1           2        3
# 8122                  8           5        3
# 8123                  5           2        3
#
# [8124 rows x 23 columns]

# %%
clean_data.to_csv("cleaned_data",index=False)
